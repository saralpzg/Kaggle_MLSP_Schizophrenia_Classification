# %% [markdown]
# # Introducción a los datos
#
# * **Características FNC:**
#
# FNC = Functional Network Connectivity. Las variables de este conjunto se refieren a valores de correlación en la conexión en mapas del cerebro (tomadas mediante MRI), independientes en el tiempo. Por lo que al final con FNC feature obtenemos una imagen de los patrones de conexiones funcionales en el tiempo. Las imágenes de MRI en cada momento indicaban el nivel de actividad en la zona.
#
# * **Características BSM:**
#
# SBM = Source-Based Morphometry. Estas variables recogen los pesos asociados a los mapas obtenidos al aplicar ICA (independent component analysis) en las concentraciones de materia gris de todos los sujetos. Si toma un valor cercano a 0 para un mapa cerebral derivado de ICA, esto indica que esas regiones del cerebro del mapa no están muy presentes, es decir, hay poca concentración de materia gris.
#
# # Análisis de los datos

# %%
# Estructuras de datos
import pandas as pd
import numpy as np

# Visualización
import matplotlib.pyplot as plt
import seaborn as sns

# Análisis
from scipy.stats import spearmanr
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %% [markdown]
# # Conjuntos de train
#
# ### Etiquetas

# %%
train_labels = pd.read_csv("data/train_labels.csv")
train_labels.shape
# Out:
# (86, 2)

# %%
train_labels.head(5)
# Out:
#        Id  Class
# 0  120873      1
# 1  135376      0
# 2  139149      0
# 3  146791      0
# 4  153870      1

# %% [markdown]
# Vamos a comprobar que no hay ningún dato incorrecto (vacío):

# %%
train_labels.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### FNC

# %%
trainFNC = pd.read_csv("data/train_FNC.csv")
trainFNC.shape
# Out:
# (86, 379)

# %%
trainFNC.head(10)
# Out:
#        Id     FNC1      FNC2     FNC3     FNC4     FNC5      FNC6      FNC7  \
# 0  120873  0.34312  0.045761 -0.13112  0.15034  0.18082  0.289160  0.069545
# 1  135376  0.28790  0.102570 -0.32343 -0.22776  0.12328  0.367020 -0.084040
# 2  139149  0.24585  0.216620 -0.12468 -0.35380  0.16150 -0.002032 -0.133020
# 3  146791  0.42090  0.331380  0.24453  0.17167  0.59223  0.431050  0.280290
# 4  153870 -0.14621 -0.468630 -0.52880 -0.50381 -0.51052 -0.029113 -0.015192
# 5  167403  0.55836  0.356460  0.35729  0.28911  0.27620  0.442630  0.318440
# 6  179564  0.11300 -0.434570 -0.71167 -0.70187  0.12693 -0.397470 -0.476990
# 7  179614  0.40232  0.062610  0.36089  0.18163  0.41605 -0.261950  0.033917
# 8  180172  0.06308 -0.182020 -0.11202 -0.29856  0.15545  0.164520  0.297350
# 9  191161 -0.18005 -0.436380 -0.73401 -0.77518 -0.50201  0.155300 -0.613400
#
#        FNC8      FNC9  ...   FNC369    FNC370   FNC371    FNC372    FNC373  \
# 0 -0.052489  0.124000  ...  0.18743  0.163770  0.17686  0.074728  0.148600
# 1  0.038793 -0.006287  ...  0.59834 -0.477880  0.26634  0.582940 -0.041272
# 2 -0.035222  0.259040  ...  0.22866 -0.000816  0.25860  0.280450 -0.644640
# 3  0.289620  0.356800  ...  0.42881  0.711570  0.56593  0.248560  0.153860
# 4  0.360170  0.005944  ...  0.41688 -0.435600  0.32104  0.392960 -0.842430
# 5 -0.110290  0.302120  ...  0.47408  0.436050  0.43982  0.419510  0.272840
# 6  0.312100  0.287610  ...  0.07131  0.759820  0.11291 -0.108470  0.175050
# 7  0.368130  0.303830  ...  0.45556  0.146950  0.35502 -0.157170  0.339770
# 8 -0.107900  0.297230  ... -0.43319  0.446300 -0.13419 -0.256200 -0.940940
# 9  0.258060  0.583350  ...  0.36090 -0.096011  0.48131  0.283100 -0.260870
#
#      FNC374   FNC375   FNC376    FNC377    FNC378
# 0  0.343230  0.17565  0.52035  0.030613  0.307740
# 1  0.630050  0.70314  0.36383 -0.207880  0.641380
# 2  0.332440  0.87074 -0.10973 -0.679160  0.323160
# 3  0.093171  0.62556  0.60391 -0.058301  0.107790
# 4  0.425080  0.86509 -0.31281 -0.829640  0.243070
# 5  0.457130  0.16197  0.81398 -0.205100 -0.062817
# 6  0.673750  0.66043  0.36516 -0.208150  0.322210
# 7  0.131410  0.58542 -0.16301  0.590690 -0.053345
# 8  0.402250  0.89480 -0.32277 -0.905100  0.360790
# 9  0.599680  0.87431  0.26035 -0.355420  0.580700
#
# [10 rows x 379 columns]

# %% [markdown]
# **Histogramas**

# %%
fig, axs = plt.subplots(126, 3, figsize=(12, 180))
axs = axs.ravel()

for i in range(378):  
    sns.histplot(trainFNC.iloc[:,i+1], ax=axs[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Mapa de calor**

# %%
corr_list = []
for column in trainFNC.columns:
    x = trainFNC[column] 
    corr_list.append(spearmanr(x, train_labels["Class"])[0]) # Sólo tomamos el coeficiente de correlación
    
# Redefinimos la lista como un array de numpy para poder transformarla a un vector columna 
# (mas cómodo de visualizar y comparar con la escala de colores de la derecha).
corr_list = np.array(corr_list)
corr_list = corr_list.reshape(corr_list.shape[0], 1)

# El primer dato se correponde a la columna ID, lo eliminamos
corr_list = corr_list[1:, :]

fig, axs = plt.subplots(2, 4, figsize=(16, 12))
batch = 50
for i in range(8):
    row_fig = i//4
    col_fig = i%4
    
    index = range(i*batch, (i*batch + batch))
    if i == 7:
        index = range(350, 378) # En el último bloque hay menos de 50 datos
        
    sns.heatmap(corr_list[index], ax=axs[row_fig, col_fig], square=True, yticklabels=index, vmin=-0.45, vmax=0.35)

plt.tight_layout()
plt.show()
# Out:
# (379, 1)
# (378, 1)

# %% [markdown]
# En general, no se observa ninguna variable que tenga un valor de correlación con la variable objetivo muy destacable.

# %% [markdown]
# **PCA**

# %%
scaler = StandardScaler()
pca = PCA()
pipeline = Pipeline([("scaling", scaler), ("pca", pca)])
trainFNC_pca = pipeline.fit_transform(trainFNC)
explained_variance = pca.explained_variance_ratio_ # Porcentaje de varianza en cada dirección encontrada
print(trainFNC_pca.shape)
print("Varianza acumulada en la última PC: ", np.cumsum(explained_variance)[-1])

plt.figure(figsize=(18, 8))
plt.plot(np.cumsum(explained_variance), "-o")
plt.xlabel("component")
plt.ylabel("explained variance")

# Mejoramos las etiquetas del eje x
n_components = len(explained_variance)
plt.xticks(np.arange(n_components), np.arange(1,n_components+1), rotation=90)

plt.grid(True)
plt.show()
# Out:
# (86, 86)
# Varianza acumulada en la última PC:  1.0000000000000002

# %% [markdown]
# _NOTA: según la documentación del método en python, "``n_components`` must be between 0 and ``min(n_samples, n_features)``=86", por ello el número de componentes principales queda cortado en 86, que es el número de muestras del que disponemos._

# %% [markdown]
# **t-SNE** (T-distributed Stochastic Neighbor Embedding) es un algoritmo diseñado para la visualización de conjuntos de datos de alta dimensionalidad. Si el número de dimensiones es muy alto, Scikit-Learn recomienda en su documentación utilizar un método de reducción de dimensionalidad previo (como PCA) para reducir el conjunto de datos a un número de dimensiones razonable (por ejemplo 50), lo que reducirá el ruido y aligerará la ejecución de t-SNE.
#
# t-SNE se ejecuta en dos pasos: en primer lugar construye una distribución de probabilidad sobre parejas de muestras en el espacio original, de forma tal que las muestras semejantes reciben alta probabilidad de ser escogidas, mientras que las muestras muy diferentes reciben baja probabilidad de ser escogidas. El concepto de "semejanza" se basa en la distancia entre puntos y densidad en las proximidades de un punto.
#
# En segundo lugar, t-SNE lleva los puntos del espacio de alta dimensionalidad al espacio de baja dimencionalidad de forma aleatoria, define una distribución de probabilidad semejante a la vista en el espacio destino (el espacio de baja dimensionalidad), y minimiza la denominada divergencia Kullback-Leibler entre las dos distribuciones con respecto a las posiciones de los puntos en el mapa (la divergencia de Kullback-Leibler mide la similitud o diferencia entre dos funciones de distribución de probabilidad). Dicho con otras palabras: t-SNE intenta reproducir la distribución que existía en el espacio original en el espacio final.
#
# Algoritmo en sklearn:
#
# * ``n_components`` (2 por defecto): Dimensiones del conjunto transformado.
# * ``perplexity`` (30 por defecto): Según la documentación de Scikit-Learn, se recomienda un valor entre 5 y 50 (mayor cuanto mayor sea el dataset), aunque se indica que el algoritmo no es muy sensible a este valor. Indica el número de vecinos más cercanos.

# %%
import warnings
warnings.filterwarnings("ignore") # Ignoramos warnings debido a versiones

n_components = 2 # Clasificación binaria

trainFNC_tsne = TSNE(n_components, init="pca", random_state=0).fit_transform(trainFNC) 
# Hay un número alto de dimensiones, se preprocesa con PCA

trainFNC_tsne2 = TSNE(n_components, random_state=0).fit_transform(trainFNC)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

axes[0].scatter(trainFNC_tsne[:, 0], trainFNC_tsne[:, 1], c=train_labels["Class"])
axes[0].title.set_text("t-SNE on FNC data (preprocessed with PCA)")

axes[1].scatter(trainFNC_tsne2[:, 0], trainFNC_tsne2[:, 1], c=train_labels["Class"])
axes[1].title.set_text("t-SNE on FNC data")

fig.tight_layout()

# %% [markdown]
# Cuando se representan los datos mediante t-SNE, si estos son preprocesados con la técnica PCA sí parece haber ciertos datos "outliers".
#
# Sin embargo, no se puede diferenciar claramente entre dos clusters, que es lo que realmente nos interesa. Vamos a probar cambiando el parámetro ``perplexity`` de t-SNE a ver si de esta forma conseguimos diferenciar dos grupos.

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(14, 8))
perplexity_values = [2, 5, 10, 25, 50, 70, 80, 100]

for i in range(8):
    row_fig = i//4
    col_fig = i%4
       
    trainFNC_tsne = TSNE(n_components, init="random", perplexity=perplexity_values[i], random_state=0).fit_transform(trainFNC) 
    
    axes[row_fig, col_fig].scatter(trainFNC_tsne[:, 0], trainFNC_tsne[:, 1], c=train_labels["Class"])
    axes[row_fig, col_fig].title.set_text(f"t-SNE on FNC data with perplexity={perplexity_values[i]}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Tampoco en estas pruebas diferenciamos los clusters. Esto nos indica que este problema no es evidente.

# %% [markdown]
# **Datos incorrectos**
#
# En este caso, los valores son correlaciones, por lo que vamos a buscar errores (valores fuera del rango [-1, 1]).

# %%
for col in trainFNC.columns[1:]:
    serie = pd.Series(trainFNC[col])
    if (serie > 1.0).any() or (serie < -1.0).any():
        print(col)

# %% [markdown]
# Parece que no hay ningún valor incorrecto.
#
# Vamos a comprobar si hay algún registro que no tenga ningún valor.

# %%
trainFNC.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### SBM

# %%
trainSBM = pd.read_csv("data/train_SBM.csv")
trainSBM.shape
# Out:
# (86, 33)

# %% [markdown]
# Todos los csv de datos de train tienen el mismo número de filas.

# %%
trainSBM.head(10)
# Out:
#        Id  SBM_map1  SBM_map2  SBM_map3  SBM_map4  SBM_map5  SBM_map6  \
# 0  120873  0.725065 -0.639254  0.353069 -0.981707 -1.419971 -0.441321
# 1  135376 -1.328855  0.502970  0.013232  1.128496 -0.070738  0.398476
# 2  139149  0.732268 -1.241554  0.654942 -0.289216  0.158316  0.029165
# 3  146791 -0.343917 -1.052519 -1.150521  0.765989  0.923129  0.674052
# 4  153870 -0.208685 -0.562697 -0.362164  1.025571  0.151690 -0.130410
# 5  167403 -0.009534 -0.371165 -0.348090  0.994007  1.113957 -1.847218
# 6  179564  1.179198 -0.349650  0.659046  1.673886  1.125081 -0.427052
# 7  179614  1.390514  1.356896  0.444022  0.134587  0.519290 -0.859090
# 8  180172  0.458459  1.499039 -1.777469  0.161159 -0.139316 -3.099610
# 9  191161  0.562708  1.636975  1.475549  0.296064  0.275471 -1.230522
#
#    SBM_map7  SBM_map8  SBM_map10  ...  SBM_map55  SBM_map61  SBM_map64  \
# 0 -0.264192  0.711579   0.641798  ...  -0.078220  -0.982331   1.070363
# 1 -0.466051 -0.435455   0.342847  ...   0.989571  -0.057543   0.371701
# 2  1.439242 -0.832816   1.285468  ...  -0.257114   0.597229   1.220756
# 3 -0.492673  1.282388  -1.914583  ...  -0.295110   0.829697  -0.450726
# 4 -1.105922  0.502029  -0.097735  ...   1.342273  -0.978412   0.158492
# 5  0.244621 -1.575156   1.425686  ...  -0.030834   1.304894   0.835378
# 6  0.111784 -0.690495   1.513205  ...   1.977324  -0.721235  -0.172975
# 7 -0.464169  0.554183   0.064726  ...  -1.160244  -0.041895   1.050680
# 8  0.136311 -0.369304   1.112714  ...   0.179212  -0.241914  -0.243907
# 9  0.622633  1.161247   1.072456  ...   2.320591  -0.873955   0.742531
#
#    SBM_map67  SBM_map69  SBM_map71  SBM_map72  SBM_map73  SBM_map74  SBM_map75
# 0   0.220316   0.776855  -2.022404   1.203256   1.083516   0.564201  -0.002006
# 1  -0.513081  -0.457550   1.476216   0.381052   0.163436   0.403782  -0.295125
# 2  -0.059213  -0.435494  -0.092971   1.090910  -0.448562  -0.508497   0.350434
# 3  -0.791032  -1.115821  -0.022296  -0.245844  -0.705539   0.061344   0.448966
# 4   0.889753   0.795368   0.738788   0.475415   2.340384   2.516038  -0.551440
# 5  -0.741826  -0.206366   0.476910   1.693937   1.269684   0.681868   1.511061
# 6  -0.558963   2.043012   1.472911  -1.277203  -0.113615  -0.049474   0.934988
# 7   0.916980  -0.665785   0.070681  -0.384861   0.060398   0.424811  -0.045953
# 8   1.287397  -1.037125   0.703299   0.626871   0.328094  -0.499501   0.516312
# 9  -0.706736  -0.863789   0.084557  -1.157955  -0.755775  -1.484624  -1.144871
#
# [10 rows x 33 columns]

# %% [markdown]
# **Histogramas**

# %%
fig, axs = plt.subplots(11, 3, figsize=(12, 18))
axs = axs.ravel()

for i in range(32):    
    sns.histplot(trainSBM.iloc[:,i+1], ax=axs[i])

fig.delaxes(axs[32])
plt.tight_layout()
plt.show()

# %% [markdown]
# En general, ninguna variable parece presentar valores muy singulares y sospechosos de ser anómalos. A excepción en todo caso de algun dato en la variable ``SBM_map74``. Lo comprobamos en el siguiente boxplot:

# %% [markdown]
# **Boxplot**

# %%
plt.figure(figsize=(16, 10))
sns.boxplot(data=trainSBM.iloc[:,1:], whis=[0, 100], width=.6, palette="vlag")
sns.stripplot(data=trainSBM.iloc[:,1:], size=4, color=".3", linewidth=0)
ax = plt.gca()
ax.tick_params(axis="x", labelrotation=45)
plt.show()

# %% [markdown]
# Ni el boxplot ni los histogramas permiten identificar valores correspondientes a un mismo individuo para ver si un paciente es consistentemente "anómalo". Más adelante se profundizará en este aspecto en la búsqueda de outliers.

# %% [markdown]
# **Mapa de calor**

# %%
corr_list = []
for column in trainSBM.columns:
    x = trainSBM[column] 
    corr_list.append(spearmanr(x, train_labels["Class"])[0]) # Sólo tomamos el coeficiente de correlación
    
# Redefinimos la lista como un array de numpy para poder transformarla a un vector columna
# (mas cómodo de visualizar y comparar con la escala de colores de la derecha).
corr_list = np.array(corr_list)
corr_list = corr_list.reshape(corr_list.shape[0], 1)

plt.figure(figsize=(2, 6))
sns.heatmap(corr_list, square=True)
plt.show()

# %% [markdown]
# Similar a como ocurre con FNC, no se encuentra ninguna variable que parezca tener una correlación significativa con la objetivo.

# %% [markdown]
# **PCA**

# %%
scaler = StandardScaler()
pca = PCA()
pipeline = Pipeline([("scaling", scaler), ("pca", pca)])
trainSBM_pca = pipeline.fit_transform(trainSBM)

explained_variance = pca.explained_variance_ratio_ # Porcentaje de varianza en cada dirección encontrada
print(trainSBM_pca.shape)
print("Varianza acumulada en la última CP: ", np.cumsum(explained_variance)[-1])

plt.figure(figsize=(12, 6))
plt.plot(np.cumsum(explained_variance),"-o")
plt.xlabel("component")
plt.ylabel("explained variance")

# Mejoramos las etiquetas del eje x
n_components = len(explained_variance)
plt.xticks(np.arange(n_components), np.arange(1,n_components+1))

plt.grid(True)
plt.show()
# Out:
# (86, 33)
# Varianza acumulada en la última CP:  1.0000000000000002

# %% [markdown]
# **t-SNE**

# %%
n_components = 2

trainSBM_tsne = TSNE(n_components, init="pca", random_state=0).fit_transform(trainSBM)
trainSBM_tsne2 = TSNE(n_components, random_state=0).fit_transform(trainSBM)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

axes[0].scatter(trainSBM_tsne[:, 0], trainSBM_tsne[:, 1], c=train_labels["Class"])
axes[0].title.set_text("t-SNE on SBM data (preprocessed with PCA)")

axes[1].scatter(trainSBM_tsne2[:, 0], trainSBM_tsne2[:, 1], c=train_labels["Class"])
axes[1].title.set_text("t-SNE on SBM data")

fig.tight_layout()

# %% [markdown]
# Resultados muy similares a los obtenidos en el apartado anterior. También en este caso, cuando se representan los datos mediante t-SNE, si estos son preprocesados con la técnica PCA sí parece haber ciertos datos "outliers".
#
# Repetimos las mismas comprobaciones, variando el parámetro ``perplexity``:

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(14, 8))
perplexity_values = [2, 5, 10, 25, 50, 70, 80, 100]

for i in range(8):
    row_fig = i//4
    col_fig = i%4
       
    trainSBM_tsne = TSNE(n_components, perplexity=perplexity_values[i], random_state=0).fit_transform(trainSBM)
    
    axes[row_fig, col_fig].scatter(trainSBM_tsne[:, 0], trainSBM_tsne[:, 1], c=train_labels["Class"])
    axes[row_fig, col_fig].title.set_text(f"t-SNE on SBM data with perplexity={perplexity_values[i]}")

plt.tight_layout()
plt.show()

# %% [markdown]
# Y del mismo modo, las proyecciones obtenidas son también muy similares a las del caso FNC. Tampoco nos permite diferenciar 2 clusters de manera sencilla.

# %% [markdown]
# **Datos incorrectos**
#
# En este caso, únicamente buscaremos datos ``null``.

# %%
trainSBM.isnull().values.any()
# Out:
# False

# %% [markdown]
# No hay datos vacíos tampoco en las variables de esta categoría.

# %% [markdown]
# ### Dataset con toda la información necesaria:

# %%
FNC_df = pd.merge(left=train_labels, right=trainFNC, left_on="Id", right_on="Id")
print(FNC_df.shape)

FNC_df.head(10)
# Out:
# (86, 380)
#        Id  Class     FNC1      FNC2     FNC3     FNC4     FNC5      FNC6  \
# 0  120873      1  0.34312  0.045761 -0.13112  0.15034  0.18082  0.289160
# 1  135376      0  0.28790  0.102570 -0.32343 -0.22776  0.12328  0.367020
# 2  139149      0  0.24585  0.216620 -0.12468 -0.35380  0.16150 -0.002032
# 3  146791      0  0.42090  0.331380  0.24453  0.17167  0.59223  0.431050
# 4  153870      1 -0.14621 -0.468630 -0.52880 -0.50381 -0.51052 -0.029113
# 5  167403      0  0.55836  0.356460  0.35729  0.28911  0.27620  0.442630
# 6  179564      1  0.11300 -0.434570 -0.71167 -0.70187  0.12693 -0.397470
# 7  179614      1  0.40232  0.062610  0.36089  0.18163  0.41605 -0.261950
# 8  180172      1  0.06308 -0.182020 -0.11202 -0.29856  0.15545  0.164520
# 9  191161      0 -0.18005 -0.436380 -0.73401 -0.77518 -0.50201  0.155300
#
#        FNC7      FNC8  ...   FNC369    FNC370   FNC371    FNC372    FNC373  \
# 0  0.069545 -0.052489  ...  0.18743  0.163770  0.17686  0.074728  0.148600
# 1 -0.084040  0.038793  ...  0.59834 -0.477880  0.26634  0.582940 -0.041272
# 2 -0.133020 -0.035222  ...  0.22866 -0.000816  0.25860  0.280450 -0.644640
# 3  0.280290  0.289620  ...  0.42881  0.711570  0.56593  0.248560  0.153860
# 4 -0.015192  0.360170  ...  0.41688 -0.435600  0.32104  0.392960 -0.842430
# 5  0.318440 -0.110290  ...  0.47408  0.436050  0.43982  0.419510  0.272840
# 6 -0.476990  0.312100  ...  0.07131  0.759820  0.11291 -0.108470  0.175050
# 7  0.033917  0.368130  ...  0.45556  0.146950  0.35502 -0.157170  0.339770
# 8  0.297350 -0.107900  ... -0.43319  0.446300 -0.13419 -0.256200 -0.940940
# 9 -0.613400  0.258060  ...  0.36090 -0.096011  0.48131  0.283100 -0.260870
#
#      FNC374   FNC375   FNC376    FNC377    FNC378
# 0  0.343230  0.17565  0.52035  0.030613  0.307740
# 1  0.630050  0.70314  0.36383 -0.207880  0.641380
# 2  0.332440  0.87074 -0.10973 -0.679160  0.323160
# 3  0.093171  0.62556  0.60391 -0.058301  0.107790
# 4  0.425080  0.86509 -0.31281 -0.829640  0.243070
# 5  0.457130  0.16197  0.81398 -0.205100 -0.062817
# 6  0.673750  0.66043  0.36516 -0.208150  0.322210
# 7  0.131410  0.58542 -0.16301  0.590690 -0.053345
# 8  0.402250  0.89480 -0.32277 -0.905100  0.360790
# 9  0.599680  0.87431  0.26035 -0.355420  0.580700
#
# [10 rows x 380 columns]

# %%
SBM_df = pd.merge(left=train_labels, right=trainSBM, left_on="Id", right_on="Id")
print(SBM_df.shape)

SBM_df.head(10)
# Out:
# (86, 34)
#        Id  Class  SBM_map1  SBM_map2  SBM_map3  SBM_map4  SBM_map5  SBM_map6  \
# 0  120873      1  0.725065 -0.639254  0.353069 -0.981707 -1.419971 -0.441321
# 1  135376      0 -1.328855  0.502970  0.013232  1.128496 -0.070738  0.398476
# 2  139149      0  0.732268 -1.241554  0.654942 -0.289216  0.158316  0.029165
# 3  146791      0 -0.343917 -1.052519 -1.150521  0.765989  0.923129  0.674052
# 4  153870      1 -0.208685 -0.562697 -0.362164  1.025571  0.151690 -0.130410
# 5  167403      0 -0.009534 -0.371165 -0.348090  0.994007  1.113957 -1.847218
# 6  179564      1  1.179198 -0.349650  0.659046  1.673886  1.125081 -0.427052
# 7  179614      1  1.390514  1.356896  0.444022  0.134587  0.519290 -0.859090
# 8  180172      1  0.458459  1.499039 -1.777469  0.161159 -0.139316 -3.099610
# 9  191161      0  0.562708  1.636975  1.475549  0.296064  0.275471 -1.230522
#
#    SBM_map7  SBM_map8  ...  SBM_map55  SBM_map61  SBM_map64  SBM_map67  \
# 0 -0.264192  0.711579  ...  -0.078220  -0.982331   1.070363   0.220316
# 1 -0.466051 -0.435455  ...   0.989571  -0.057543   0.371701  -0.513081
# 2  1.439242 -0.832816  ...  -0.257114   0.597229   1.220756  -0.059213
# 3 -0.492673  1.282388  ...  -0.295110   0.829697  -0.450726  -0.791032
# 4 -1.105922  0.502029  ...   1.342273  -0.978412   0.158492   0.889753
# 5  0.244621 -1.575156  ...  -0.030834   1.304894   0.835378  -0.741826
# 6  0.111784 -0.690495  ...   1.977324  -0.721235  -0.172975  -0.558963
# 7 -0.464169  0.554183  ...  -1.160244  -0.041895   1.050680   0.916980
# 8  0.136311 -0.369304  ...   0.179212  -0.241914  -0.243907   1.287397
# 9  0.622633  1.161247  ...   2.320591  -0.873955   0.742531  -0.706736
#
#    SBM_map69  SBM_map71  SBM_map72  SBM_map73  SBM_map74  SBM_map75
# 0   0.776855  -2.022404   1.203256   1.083516   0.564201  -0.002006
# 1  -0.457550   1.476216   0.381052   0.163436   0.403782  -0.295125
# 2  -0.435494  -0.092971   1.090910  -0.448562  -0.508497   0.350434
# 3  -1.115821  -0.022296  -0.245844  -0.705539   0.061344   0.448966
# 4   0.795368   0.738788   0.475415   2.340384   2.516038  -0.551440
# 5  -0.206366   0.476910   1.693937   1.269684   0.681868   1.511061
# 6   2.043012   1.472911  -1.277203  -0.113615  -0.049474   0.934988
# 7  -0.665785   0.070681  -0.384861   0.060398   0.424811  -0.045953
# 8  -1.037125   0.703299   0.626871   0.328094  -0.499501   0.516312
# 9  -0.863789   0.084557  -1.157955  -0.755775  -1.484624  -1.144871
#
# [10 rows x 34 columns]

# %% [markdown]
# ### Dataset completo:

# %%
train_data = pd.merge(left=trainFNC, right=trainSBM, left_on="Id", right_on="Id")
print(train_data.shape)
train_data.head(10)
# Out:
# (86, 411)
#        Id     FNC1      FNC2     FNC3     FNC4     FNC5      FNC6      FNC7  \
# 0  120873  0.34312  0.045761 -0.13112  0.15034  0.18082  0.289160  0.069545
# 1  135376  0.28790  0.102570 -0.32343 -0.22776  0.12328  0.367020 -0.084040
# 2  139149  0.24585  0.216620 -0.12468 -0.35380  0.16150 -0.002032 -0.133020
# 3  146791  0.42090  0.331380  0.24453  0.17167  0.59223  0.431050  0.280290
# 4  153870 -0.14621 -0.468630 -0.52880 -0.50381 -0.51052 -0.029113 -0.015192
# 5  167403  0.55836  0.356460  0.35729  0.28911  0.27620  0.442630  0.318440
# 6  179564  0.11300 -0.434570 -0.71167 -0.70187  0.12693 -0.397470 -0.476990
# 7  179614  0.40232  0.062610  0.36089  0.18163  0.41605 -0.261950  0.033917
# 8  180172  0.06308 -0.182020 -0.11202 -0.29856  0.15545  0.164520  0.297350
# 9  191161 -0.18005 -0.436380 -0.73401 -0.77518 -0.50201  0.155300 -0.613400
#
#        FNC8      FNC9  ...  SBM_map55  SBM_map61  SBM_map64  SBM_map67  \
# 0 -0.052489  0.124000  ...  -0.078220  -0.982331   1.070363   0.220316
# 1  0.038793 -0.006287  ...   0.989571  -0.057543   0.371701  -0.513081
# 2 -0.035222  0.259040  ...  -0.257114   0.597229   1.220756  -0.059213
# 3  0.289620  0.356800  ...  -0.295110   0.829697  -0.450726  -0.791032
# 4  0.360170  0.005944  ...   1.342273  -0.978412   0.158492   0.889753
# 5 -0.110290  0.302120  ...  -0.030834   1.304894   0.835378  -0.741826
# 6  0.312100  0.287610  ...   1.977324  -0.721235  -0.172975  -0.558963
# 7  0.368130  0.303830  ...  -1.160244  -0.041895   1.050680   0.916980
# 8 -0.107900  0.297230  ...   0.179212  -0.241914  -0.243907   1.287397
# 9  0.258060  0.583350  ...   2.320591  -0.873955   0.742531  -0.706736
#
#    SBM_map69  SBM_map71  SBM_map72  SBM_map73  SBM_map74  SBM_map75
# 0   0.776855  -2.022404   1.203256   1.083516   0.564201  -0.002006
# 1  -0.457550   1.476216   0.381052   0.163436   0.403782  -0.295125
# 2  -0.435494  -0.092971   1.090910  -0.448562  -0.508497   0.350434
# 3  -1.115821  -0.022296  -0.245844  -0.705539   0.061344   0.448966
# 4   0.795368   0.738788   0.475415   2.340384   2.516038  -0.551440
# 5  -0.206366   0.476910   1.693937   1.269684   0.681868   1.511061
# 6   2.043012   1.472911  -1.277203  -0.113615  -0.049474   0.934988
# 7  -0.665785   0.070681  -0.384861   0.060398   0.424811  -0.045953
# 8  -1.037125   0.703299   0.626871   0.328094  -0.499501   0.516312
# 9  -0.863789   0.084557  -1.157955  -0.755775  -1.484624  -1.144871
#
# [10 rows x 411 columns]

# %% [markdown]
# # Outliers en train
#
# El problema de los datos outliers en esta clasificación es especialmente importante, ya que el volumen de los datos disponibles para el entrenamiento es muy reducido (86 pacientes) y por tanto, los modelos serán más sensibles a la presencia de datos anómalos.
#
# Se considerarán outliers todas aquellas muestras cuyos datos sean consistentemente anómalos. Sin embargo, como tampoco se desea podar excesivamente un dataset ya bastante reducido, la exigencia será alta y el criterio adoptado para tratar de "consistentemente anómalo" un registro es exigir un 80% de sus datos como outliers (por debajo o por encima de los percentiles 10 y 90 de la variable respectivamente).

# %%
percent10, percent90 = [], []

for col in train_data.columns[1:]:
    serie = pd.Series(train_data[col])
    percent10.append(np.percentile(serie, 10))
    percent90.append(np.percentile(serie, 90))

threshold = round(train_data.shape[1]*0.8) # Al menos 80% de los valores de la fila (paciente) son sospechosos
print("Si un paciente presenta más de {} datos anómalos, sus datos se considerarán 'outliers'.".format(threshold))
outliers = [] # Guarda los IDs de los pacientes consistentemente anómalos
for idx, row in train_data.iterrows():
    num_outliers = (row[1:] < percent10).sum()
    if num_outliers > threshold:
        outliers.append(row[0])
        
outliers
# Out:
# Si un paciente presenta más de 329 datos anómalos, sus datos se considerarán 'outliers'.
# []

# %% [markdown]
# Además, vamos a comprobar que las muestras de ambos conjuntos están balanceadas, es decir, ninguna etiquetas tiene un volumen de muestras muy superior al volumen de la contraria.

# %%
plt.figure(figsize=(5, 4))
control_group = train_labels[train_labels["Class"]==0]
sick = train_labels[train_labels["Class"]==1]
labels = ["Grupo de control", "Pacientes de esquizofrenia"]
plt.bar(labels, [len(control_group), len(sick)], width=0.25, align="center")
plt.xlim(-0.45, len(labels) -1 + 0.45)
plt.xticks(fontsize=12)
plt.show()

# %% [markdown]
# El anterior barplot muestra que las dos clases están bastante equilibradas.

# %% [markdown]
# # Conjuntos de test
#
# No se dispone de las etiquetas. No se podrán comprobar por ejemplo correlaciones. Tampoco será necesario comprobar pacientes "outliers" ya que no nos basaremos en estos datos para entrenar los modelos y además el volumen de los mismos es mucho mayor.

# %% [markdown]
# ### FNC

# %%
testFNC = pd.read_csv("data/test_FNC.csv")
testFNC.shape
# Out:
# (119748, 379)

# %% [markdown]
# El número de datos es mucho mayor (conjunto de train dispone únicamente de 86 filas).

# %%
testFNC.head(10)
# Out:
#        Id      FNC1      FNC2      FNC3      FNC4      FNC5      FNC6  \
# 0  100004  0.476127  0.064466  0.053238 -0.608133  0.073988 -0.637038
# 1  100015  0.013833  0.267183  0.232178 -0.167151 -0.261327  0.191869
# 2  100026 -0.435452  0.046780  0.243742  0.397030 -0.147821  0.173620
# 3  100030 -0.204510 -0.036735 -0.760705 -0.740495  0.064668  0.349926
# 4  100047  0.599435 -0.166441  0.122431  0.011539  0.346906 -0.017430
# 5  100052  0.454620 -0.622771 -0.279665 -0.064160  0.088577  0.177451
# 6  100056 -0.322998  0.086923 -0.512834  0.473169  0.221891  0.615062
# 7  100061  0.741983  0.247769  0.213151  0.338811  0.707186  0.284273
# 8  100067 -0.002581  0.392633  0.168592  0.469304  0.531180  0.173910
# 9  100068  0.157915  0.063540 -0.061450 -0.441967  0.251576  0.399884
#
#        FNC7      FNC8      FNC9  ...    FNC369    FNC370    FNC371    FNC372  \
# 0  0.113556 -0.192434 -0.004025  ...  0.482131  0.022525 -0.034251 -0.103902
# 1  0.406493  0.088761  0.177048  ...  0.387964  0.288442  0.503947 -0.221215
# 2 -0.461963 -0.610736  0.419753  ... -0.388256  0.052361  0.759901  0.478927
# 3 -0.273826 -0.174384 -0.120248  ...  0.406804  0.169224  0.001855  0.324120
# 4 -0.274734  0.211510  0.151012  ...  0.681542  0.306077  0.245725  0.222826
# 5 -0.062679 -0.238675  0.304354  ...  0.669448 -0.144019  0.045520  0.520519
# 6  0.023196  0.001180  0.332047  ...  0.517704 -0.153737  0.216250  0.583100
# 7 -0.398987  0.104485 -0.371600  ...  0.389994  0.431791  0.092224  0.293644
# 8 -0.484592  0.295530  0.288903  ... -0.249275 -0.453223  0.391129  0.819428
# 9 -0.471428 -0.502345 -0.184419  ...  0.001235  0.308326 -0.292834  0.326730
#
#      FNC373    FNC374    FNC375    FNC376    FNC377    FNC378
# 0 -0.497701  0.079286  0.265937  0.379066 -0.630483 -0.309032
# 1 -0.949426  0.340575  0.767685  0.417164  0.194081 -0.218685
# 2 -0.164136 -0.096020  0.607880  0.099879 -0.429554  0.453645
# 3 -0.212088  0.344033  0.234452  0.214809 -0.138947  0.436006
# 4 -0.492551  0.544921  0.665504 -0.261091  0.026635  0.341486
# 5 -0.820024  0.376321  0.870507  0.463833 -0.576071  0.770549
# 6  0.584275  0.849461  0.165957 -0.395187 -0.459451  0.613839
# 7  0.286467  0.385819 -0.653168  0.231916 -0.535986  0.604733
# 8 -0.109781 -0.019199  0.868363  0.513662 -0.155854  0.355647
# 9  0.421712  0.365903  0.557932  0.557631  0.194945 -0.180590
#
# [10 rows x 379 columns]

# %% [markdown]
# **Histogramas**

# %%
fig, axs = plt.subplots(126, 3, figsize=(12, 180))
axs = axs.ravel()

for i in range(378):  
    sns.histplot(testFNC.iloc[:,i+1], ax=axs[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Datos incorrectos**

# %%
for col in testFNC.columns[1:]:
    serie = pd.Series(trainFNC[col])
    if (serie > 1.0).any() or (serie < -1.0).any():
        print(col)

# %%
testFNC.isnull().values.any()
# Out:
# False

# %% [markdown]
# No hay ni valores vacíos ni fuera de rango ([-1, 1]).

# %% [markdown]
# ### SBM

# %%
testSBM = pd.read_csv("data/test_SBM.csv")
testSBM.shape
# Out:
# (119748, 33)

# %%
testSBM.head(10)
# Out:
#        Id  SBM_map1  SBM_map2  SBM_map3  SBM_map4  SBM_map5  SBM_map6  \
# 0  100004  1.154881  3.627246  0.146076 -0.677521  0.951169  0.482531
# 1  100015 -1.608977 -0.125656  2.232224  1.013575  1.227375  0.296077
# 2  100026  1.611464  1.859449 -0.959714 -0.713587  0.826513 -0.405989
# 3  100030 -0.283111 -0.418010  1.962834 -0.342130 -0.939108  0.929705
# 4  100047 -0.688717  1.951002  1.512576 -0.854993  1.059652 -0.179238
# 5  100052 -2.245835  3.047490  0.887599  1.053941 -0.621158  1.108795
# 6  100056 -0.486466 -1.115065 -0.148287 -0.321722  1.950143 -0.259730
# 7  100061  0.226290 -0.769410 -1.424939 -0.636175 -0.878731  1.531167
# 8  100067  2.174836  1.448771  2.640777 -0.451982  1.030843 -1.016189
# 9  100068 -0.793736  1.313857  0.686430 -0.115100  1.687633  0.266068
#
#    SBM_map7  SBM_map8  SBM_map10  ...  SBM_map55  SBM_map61  SBM_map64  \
# 0 -2.404130 -0.715182  -0.475299  ...  -0.451994   1.123770   2.083006
# 1 -0.612468 -1.610222  -0.136698  ...   0.696987   1.397832   1.046136
# 2 -0.752907 -0.484180  -1.212576  ...   0.160145   1.906989  -2.661633
# 3  1.041755 -1.073416  -0.815344  ...   0.974828  -1.997087  -2.083782
# 4 -1.775324  0.649346   1.616116  ...  -0.789153   1.578984   1.402592
# 5  1.551291 -2.229469   0.763336  ...   1.039762   2.356631   0.431598
# 6 -0.952700 -0.090597   1.234362  ...  -1.666868   1.277421  -0.018488
# 7  2.585980 -1.607612   0.561075  ...  -0.285274   2.008654   0.122802
# 8 -1.685961 -2.029091  -0.960480  ...  -0.205254   0.108215   0.659699
# 9  1.348152  1.543148   0.425215  ...   0.545245  -1.128903  -2.376076
#
#    SBM_map67  SBM_map69  SBM_map71  SBM_map72  SBM_map73  SBM_map74  SBM_map75
# 0   1.145440  -0.067608   1.202529   0.851587   0.451583  -0.159739   0.192076
# 1  -0.191733  -2.192023  -0.369276   0.822225  -0.109342  -0.580476   0.174160
# 2  -0.193911   0.440873   0.641739   0.918397  -0.758046   0.154701  -0.476647
# 3   1.154107  -0.643947   2.332424   0.659124  -0.809445   0.558960   2.790871
# 4  -1.230440   0.296686   2.806314   0.427184  -0.240682  -0.196948  -1.544345
# 5  -1.059533  -0.936320   1.303550   0.105144   0.489147   0.797539  -0.585290
# 6  -1.577980   1.034835  -0.026758  -0.518825  -0.739487  -0.023227  -1.358591
# 7   1.905865   0.974481  -0.918039   0.084806   0.829912  -1.855395  -2.023847
# 8  -0.743904  -0.088341   0.244255   0.327796   0.266319  -0.324512  -0.133684
# 9   2.349007   0.581527   2.339391   1.499372   0.773951   0.299564   2.043024
#
# [10 rows x 33 columns]

# %% [markdown]
# **Histogramas**

# %%
fig, axs = plt.subplots(11, 3, figsize=(12, 18))
axs = axs.ravel()

for i in range(32):    
    sns.histplot(testSBM.iloc[:,i+1], ax=axs[i])

fig.delaxes(axs[32])
plt.tight_layout()
plt.show()

# %% [markdown]
# **Boxplot**
#
# En este conjunto, la cantidad de puntos es excesiva como para representarlos sobre las cajas.

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=testSBM.iloc[:,1:], whis=[0, 100], width=.6, palette="vlag")
ax = plt.gca()
ax.tick_params(axis="x", labelrotation=45)
plt.show()

# %% [markdown]
# **Datos incorrectos**

# %%
testSBM.isnull().values.any()
# Out:
# False

# %% [markdown]
# No hay datos vacíos.
